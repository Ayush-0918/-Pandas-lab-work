# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-0918/-Pandas-lab-work/blob/main/Pandas_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name":["Aayu","Varshu","Aman","Vishal"],
    "marks":[92,96,78,67],
    "roll no":[1,2,3,4]
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  marks  roll no
# 0    Aayu     92        1
# 1  Varshu     96        2
# 2    Aman     78        3
# 3  Vishal     67        4

# %%
df.to_csv('friends.csv')

# %%
df.to_excel('friends1.xlsx')

# %%
df.head(2)
# Out:
#      name  marks  roll no
# 0    Aayu     92        1
# 1  Varshu     96        2

# %%
df.tail(2)
# Out:
#      name  marks  roll no
# 2    Aman     78        3
# 3  Vishal     67        4

# %%
df.describe()
# Out:
#            marks   roll no
# count   4.000000  4.000000
# mean   83.250000  2.500000
# std    13.301002  1.290994
# min    67.000000  1.000000
# 25%    75.250000  1.750000
# 50%    85.000000  2.500000
# 75%    93.000000  3.250000
# max    96.000000  4.000000

# %%
friends_marks = pd.read_csv('friends.csv')

# %%
friends_marks
# Out:
#    Unnamed: 0    name  marks  roll no
# 0           0    Aayu     92        1
# 1           1  Varshu     96        2
# 2           2    Aman     78        3
# 3           3  Vishal     67        4

# %%
friends_marks['marks']
# Out:
# 0    92
# 1    96
# 2    78
# 3    67
# Name: marks, dtype: int64

# %%
friends_marks['marks'][1]=93
# Out:
# /tmp/ipykernel_3510/1264105317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   friends_marks['marks'][1]=93

# %%
friends_marks
# Out:
#    Unnamed: 0    name  marks  roll no
# 0           0    Aayu     92        1
# 1           1  Varshu     93        2
# 2           2    Aman     78        3
# 3           3  Vishal     67        4

# %%
friends_marks.to_csv('friends.csv')

# %%
ser = pd.Series(np.random.rand(10))

# %%
ser
# Out:
# 0    0.585363
# 1    0.562465
# 2    0.671644
# 3    0.488674
# 4    0.123982
# 5    0.953074
# 6    0.885890
# 7    0.913882
# 8    0.848734
# 9    0.668847
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(34,5),index=np.arange(34))

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0.959886  0.511836  0.599295  0.403346  0.797335
# 1   0.130536  0.801234  0.585316  0.891765  0.559614
# 2   0.094989  0.801981  0.959394  0.626865  0.931248
# 3   0.679199  0.299262  0.944816  0.182108  0.926390
# 4   0.953423  0.960116  0.776280  0.952343  0.569990
# 5   0.349025  0.831474  0.693995  0.349263  0.956159
# 6   0.744081  0.270258  0.535528  0.261188  0.288204
# 7   0.612529  0.682731  0.471572  0.886344  0.235052
# 8   0.947983  0.387455  0.367191  0.662090  0.824582
# 9   0.833467  0.425049  0.651411  0.389147  0.741462
# 10  0.228807  0.124590  0.072217  0.470681  0.267328
# 11  0.868053  0.161427  0.791005  0.174471  0.683739
# 12  0.352525  0.231497  0.046574  0.153763  0.737501
# 13  0.271811  0.723660  0.493896  0.853978  0.059526
# 14  0.814683  0.376099  0.409639  0.092887  0.263281
# 15  0.139665  0.161190  0.449411  0.553088  0.264471
# 16  0.637234  0.243304  0.324089  0.024889  0.601560
# ...

# %%
type(newdf)
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0
# 8   None  0.589358  0.062945  0.990869  0.375793  None
# 9   None  0.132913  0.756018  0.902764  0.234456  None
# 10  None  0.386244  0.434552  0.275064  0.440463  None
# 11  None  0.930465  0.729309  0.537067  0.641289  None
# 12  None  0.417315  0.525030  0.202146  0.442074  None
# 13  None  0.213845  0.636308  0.905199  0.850520  None
# 14  None  0.780799  0.485089  0.552300  0.917139  None
# 15  None  0.609265  0.537341  0.938665  0.594529  None
# ...

# %%
newdf.loc[:,[0]] = 10

# %%
newdf
# Out:
#      0         1         2         3         4     0
# 0   10  0.694329  0.235491  0.998767  0.209865  None
# 1   10  0.797940  0.419027  0.407929  0.462918  None
# 2   10  0.155867  0.181690  0.108672  0.704496  None
# 3   10  0.116881  0.414554  0.496279  0.739244  None
# 4   10  0.727010  0.408157  0.488876  0.953988  None
# 5   10  0.945395  0.588121  0.216811  0.016850  None
# 6   10  0.126271  0.816297  0.280097  0.232415  None
# 7   10  0.496204  0.865002  0.720784  0.395159  None
# 8   10  0.589358  0.062945  0.990869  0.375793  None
# 9   10  0.132913  0.756018  0.902764  0.234456  None
# 10  10  0.386244  0.434552  0.275064  0.440463  None
# 11  10  0.930465  0.729309  0.537067  0.641289  None
# 12  10  0.417315  0.525030  0.202146  0.442074  None
# 13  10  0.213845  0.636308  0.905199  0.850520  None
# 14  10  0.780799  0.485089  0.552300  0.917139  None
# 15  10  0.609265  0.537341  0.938665  0.594529  None
# 16  10  0.797182  0.992493  0.979790  0.877888  None
# ...

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Aritra'],
                   'Age': [25, 30, 35],
                    'Location': ['Seattle', 'New York', 'Kona']},
                   index=([10, 20, 30]))

# %%
df
# Out:
#       Name  Age  Location
# 10   Alice   25   Seattle
# 20     Bob   30  New York
# 30  Aritra   35      Kona

# %%
df.head()
# Out:
#       Name  Age  Location
# 10   Alice   25   Seattle
# 20     Bob   30  New York
# 30  Aritra   35      Kona

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 10 to 30
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df = pd.DataFrame({

    'A': [1, 2, 3],

    'B': [4, 5, 6]

})

# %%
df.describe()
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %%
df.mean()
# Out:
# A    2.0
# B    5.0
# dtype: float64

# %%
df.corr()
# Out:
#      A    B
# A  1.0  1.0
# B  1.0  1.0

# %%
df.max()
# Out:
# A    3
# B    6
# dtype: int64

# %%
df.median()
# Out:
# A    2.0
# B    5.0
# dtype: float64

# %%
df.std()
# Out:
# A    1.0
# B    1.0
# dtype: float64
